# %%
import pandas as pd

# %%
imdb = pd.read_csv('imdb_titles.tsv',sep='\t')
netflix = pd.read_csv('netflix_titles.csv')
ratings = pd.read_csv('ratings.tsv',sep='\t')
# Out:
# C:\Users\dhyey\AppData\Local\Temp\ipykernel_19796\4102194071.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb = pd.read_csv('imdb_titles.tsv',sep='\t')

# %%
imdb
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11601724  tt9916848  tvEpisode              Episode #3.17
# 11601725  tt9916850  tvEpisode              Episode #3.19
# 11601726  tt9916852  tvEpisode              Episode #3.20
# 11601727  tt9916856      short                   The Wind
# 11601728  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
imdb.drop(['tconst', 'titleType', 'originalTitle', 'isAdult', 'endYear', 'runtimeMinutes', 'genres'], axis=1)
# Out:
#                        primaryTitle startYear
# 0                        Carmencita      1894
# 1            Le clown et ses chiens      1892
# 2                      Poor Pierrot      1892
# 3                       Un bon bock      1892
# 4                  Blacksmith Scene      1893
# ...                             ...       ...
# 11601724              Episode #3.17      2009
# 11601725              Episode #3.19      2010
# 11601726              Episode #3.20      2010
# 11601727                   The Wind      2015
# 11601728  Horrid Henry Knows It All      2014
#
# [11601729 rows x 2 columns]

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix = netflix.drop(['show_id', 'type', 'director', 'cast', 'country', 'rating', 'duration', 'listed_in', 'description'], axis=1)

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2148
# 1        tt0000002            5.5       291
# 2        tt0000003            6.5      2184
# 3        tt0000004            5.3       187
# 4        tt0000005            6.2      2931
# ...            ...            ...       ...
# 1559469  tt9916846            5.8         6
# 1559470  tt9916848            5.8         6
# 1559471  tt9916850            5.8         6
# 1559472  tt9916852            5.8         6
# 1559473  tt9916880            7.7        10
#
# [1559474 rows x 3 columns]

# %%
imdb_ratings = pd.merge(imdb, ratings, on='tconst', how='inner')

# %%
imdb_ratings = imdb_ratings.drop(['tconst', 'titleType', 'originalTitle', 'isAdult', 'endYear', 'runtimeMinutes', 'genres'], axis=1)

# %%
imdb_ratings['primaryTitle_clean'] = imdb_ratings['primaryTitle'].str.lower().str.strip()
netflix['title_clean'] = netflix['title'].str.lower().str.strip()

# %%
imdb_no_dup = imdb_ratings.sort_values('numVotes', ascending=False).drop_duplicates(subset='primaryTitle_clean') # Remove duplicates, keep instance with greatest number of votes.

# %%
netflix_titles = pd.merge(imdb_no_dup, netflix, left_on='primaryTitle_clean', right_on='title_clean', how='inner')

# %%
netflix_titles['date_added'] = merged['date_added'].str.strip()
netflix_titles['date_added'] = pd.to_datetime(merged['date_added'], errors='coerce')

# %%
netflix_titles
# Out:
#                                        primaryTitle startYear  averageRating  \
# 0                                         Inception      2010            8.8
# 1                                      Pulp Fiction      1994            8.9
# 2                                      Breaking Bad      2008            9.5
# 3                                        The Matrix      1999            8.7
# 4     The Lord of the Rings: The Return of the King      2003            9.0
# ...                                             ...       ...            ...
# 7430                                        Posesif      2023            8.0
# 7431                                  Miss Culinary      2019            7.4
# 7432                                 Death Can Wait      2011            7.8
# 7433                  Wonho Chung: Live in New York      2014            6.0
# 7434                      The Lovers and the Despot      2016            7.2
#
# ...
